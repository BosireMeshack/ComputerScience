# %%
print("I am exploring APIs today")
# Out:
# I am exploring APIs today

# %%
pip install requests
# Out:
# ...
#   Obtaining dependency information for requests from https://files.pythonhosted.org/packages/f9/9b/335f9764261e915ed497fcdeb11df5dfd6f7bf257d4a6a2a686d80da4d54/requests-2.32.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/72/80/41ef5d5a7935d2d3a773e3eaebf0a9350542f2cab4eac59a7a4741fbbbbe/charset_normalizer-3.4.1-cp311-cp311-macosx_10_9_universal2.whl.metadata
# ...
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/76/c6/c88e154df9c4e1a2a66ccf0005a88dfb2650c1dffb6f5ce603dfbd452ce3/idna-3.10-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/c8/19/4ec628951a74043532ca2cf5d97b7b14863931476d117c471e8e2b1eb39f/urllib3-2.3.0-py3-none-any.whl.metadata
# ...

# %%
#Dog API

import requests
response = requests.get("https://api.thedogapi.com/v1/images/search")
print(response.json())
# Out:
# [{'id': 'iYNlO0y4T', 'url': 'https://cdn2.thedogapi.com/images/iYNlO0y4T.jpg', 'width': 1080, 'height': 1080}]

# %%
# JSON placeholder API
import requests
response = requests.get("https://jsonplaceholder.typicode.com/users/1")
print(response.json())
# Out:
# {'id': 1, 'name': 'Leanne Graham', 'username': 'Bret', 'email': 'Sincere@april.biz', 'address': {'street': 'Kulas Light', 'suite': 'Apt. 556', 'city': 'Gwenborough', 'zipcode': '92998-3874', 'geo': {'lat': '-37.3159', 'lng': '81.1496'}}, 'phone': '1-770-736-8031 x56442', 'website': 'hildegard.org', 'company': {'name': 'Romaguera-Crona', 'catchPhrase': 'Multi-layered client-server neural-net', 'bs': 'harness real-time e-markets'}}

# %%
#Github API
import requests
response = requests.get("https://api.github.com/repos/BosireMeshack/Airbnb")
print(response.json())
# Out:
# {'id': 955786997, 'node_id': 'R_kgDOOPgm9Q', 'name': 'Airbnb', 'full_name': 'BosireMeshack/Airbnb', 'private': False, 'owner': {'login': 'BosireMeshack', 'id': 72230553, 'node_id': 'MDQ6VXNlcjcyMjMwNTUz', 'avatar_url': 'https://avatars.githubusercontent.com/u/72230553?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/BosireMeshack', 'html_url': 'https://github.com/BosireMeshack', 'followers_url': 'https://api.github.com/users/BosireMeshack/followers', 'following_url': 'https://api.github.com/users/BosireMeshack/following{/other_user}', 'gists_url': 'https://api.github.com/users/BosireMeshack/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/BosireMeshack/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/BosireMeshack/subscriptions', 'organizations_url': 'https://api.github.com/users/BosireMeshack/orgs', 'repos_url': 'https://api.github.com/users/BosireMeshack/repos', 'events_url': 'https://api.github.com/users/BosireMeshack/events{/p
# ...

# %%
#OpenWeather API

import requests
response = requests.get("https://api.openweathermap.org/data/2.5/weather?q=Budapest,hu&APPID=494d6e76b0c50c8aaa3a0f8c1322e631")
print(response.json())
# Out:
# {'coord': {'lon': 19.0399, 'lat': 47.498}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 291.89, 'feels_like': 290.89, 'temp_min': 290.44, 'temp_max': 292.05, 'pressure': 1018, 'humidity': 41, 'sea_level': 1018, 'grnd_level': 996}, 'visibility': 10000, 'wind': {'speed': 2.57, 'deg': 190}, 'clouds': {'all': 0}, 'dt': 1744459686, 'sys': {'type': 2, 'id': 2009313, 'country': 'HU', 'sunrise': 1744430445, 'sunset': 1744478882}, 'timezone': 7200, 'id': 3054643, 'name': 'Budapest', 'cod': 200}

# %%
#JSONPlaceholder API 

import requests
response = requests.get("https://my-json-server.typicode.com/BosireMeshack/ComputerScience")
#response = requests.get("https://my-json-server.typicode.com/typicode/demo")
print(response.text)
# Out:
# <!DOCTYPE html><html><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width" initial-scale="1"/><title>My JSON Server - Fake online REST server for teams</title><link rel="stylesheet" href="//fonts.googleapis.com/css?family=Roboto:300,300italic,700,700italic"/><link rel="stylesheet" href="//cdn.rawgit.com/necolas/normalize.css/master/normalize.css"/><link rel="stylesheet" href="//cdn.rawgit.com/milligram/milligram/master/dist/milligram.min.css"/><link rel="stylesheet" href="/styles/index.css"/><link rel="stylesheet" href="//cdn.jsdelivr.net/highlight.js/9.10.0/styles/color-brewer.min.css"/><link rel="stylesheet" href="//code.ionicframework.com/ionicons/2.0.1/css/ionicons.min.css"/></head><body><div class="sponsor"><a href="https://mockend.com">Need more? Private repo, random values, REST+GraphQL... check our sponsor Mockend</a></div><div class="header"><div class="container narrow"><div class="row"><div class="column"><a href="/">My JSON Server</a>  <span clas
# ...
