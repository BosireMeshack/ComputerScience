# %%
print("I am using Jupyter")
# Out:
# I am using Jupyter

# %%
from datetime import datetime

dt1 = datetime(2020, 9, 29, 14, 41, 0)

dt2 = datetime(2020, 9, 28, 14, 41, 0)

print(dt1 - dt2)
# Out:
# 1 day, 0:00:00

# %%
import calendar

print(calendar.weekheader(10))
# Out:
#   Monday    Tuesday   Wednesday   Thursday    Friday    Saturday    Sunday

# %%
foo = [i + i for i in range(5)]

print (foo)
# Out:
# [0, 2, 4, 6, 8]

# %%
import errno

try:

    stream = open("file", "rb")

    print("exists")

    stream.close()

except IOError as error:

     if error.errno == errno.ENOENT:

          print("absent")

     else:

          print("unknown")
# Out:
# absent

# %%
list_1 = ["A", "B", "C"]

list_2 = list_1

list_3 = list_2

del list_1[0]

del list_2[:]

print(list_3)




list_1 = ["A", "B", "C"]

list_2 = list_1[:]

list_3 = list_2[:]

del list_1[0]

del list_2[0]

print(list_3)




def hi():

     return

     print("Hi!")

hi()

for ch in "abc":

     print(chr(ord(ch) + 1), end=' ')

text = "こんにちは世界"  # Japanese: Hello, World
emoji = "\U0001F600"  # 😀
print(text, emoji)

s1 = '12.0'

#i = int(s1)

#s2 = str(i)

#f = float(s2)

#print(s1 == s2) 

from datetime import datetime

dt1 = datetime(2020, 9, 29, 14, 41, 0)

dt2 = datetime(2020, 9, 28, 14, 41, 0)

print(dt1 - dt2)
# Out:
# []
# ['A', 'B', 'C']
# b c d こんにちは世界 😀
# 1 day, 0:00:00

# %%
class Vowels:

     def __init__(self):

            self.vow = "aeiouy " # Yes, we know that y is not always considered a vowel.       self.pos = 0

     def __iter__(self):

          return self

     def __next__(self):

           if self.pos == len(self.vow):

              raise StopIteration

           self.pos += 1

           return self.vow[self.pos - 1]

vowels = Vowels()

for v in vowels:

     print(v, end=' ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 23
#      19            return self.vow[self.pos - 1]
#      21 vowels = Vowels()
# ---> 23 for v in vowels:
#      25      print(v, end=' ')
#
# Cell In[3], line 13, in Vowels.__next__(self)
#      11 def __next__(self):
# ---> 13       if self.pos == len(self.vow):
#      15          raise StopIteration
#      17       self.pos += 1
#
# AttributeError: 'Vowels' object has no attribute 'pos'
